# %% [markdown]
# # ゼロから始めすデータサイエンス 3章 データの可視化

# %%
from matplotlib import pyplot as plt

years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.6, 5979.6, 10289.7, 14958.3]

plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

plt.title("Nominal GDP")

plt.ylabel("Billions of $")
plt.show()

# %%
# 棒グラフ

from matplotlib import pyplot as plt

movies =["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscar = [5, 11, 3, 8, 10]

xs = [i + 0.1 for i, _ in enumerate(movies)]

plt.bar(xs, num_oscar)

plt.ylabel("# of Academy Awards")
plt.title("My Favorite Movies")
plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies)

plt.show()

# %%
# histogram

from  matplotlib import pyplot as plt
from collections import Counter

grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]
decile = lambda grade: grade // 10 * 10
histogram = Counter(decile(grade) for grade in grades)

plt.bar([x - 4 for x in histogram.keys()], histogram.values(), 8)
plt.axis([-5, 105, 0, 5])

plt.xticks([10 * i for i in range(11)])
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")
plt.show()

# %%
# 間違った印象を与える棒グラフ

from matplotlib import pyplot as plt

mentions = [500, 505]
years = [2013, 2014]

plt.bar([2012.6, 2013.6], mentions, 0.8)
plt.xticks(years)

plt.ylabel("# of times I heard someone sat 'data science'")

# 省略すると1,2と共に+2.013e3とX軸上に表示されてしまう。
plt.ticklabel_format(useOffset=False)

# 500以上の部分だけを表示すると、誤った印象を与える
plt.axis([2012.5, 2014.5, 499, 506])
plt.title("Look at the 'Huge' Increase!")
plt.show()

# %%
# 適切な棒グラフ

from matplotlib import pyplot as plt

mentions = [500, 505]
years = [2013, 2014]

plt.bar([2012.6, 2013.6], mentions, 0.8)
plt.xticks(years)

plt.ylabel("# of times I heard someone sat 'data science'")

# 省略すると1,2と共に+2.013e3とX軸上に表示されてしまう。
plt.ticklabel_format(useOffset=False)

plt.axis([2012.5, 2014.5, 0, 550])
plt.title("Not So Huge Anymore")
plt.show()

# %%
# 折れ線グラフ
# 値の動きを見るのに適している

from matplotlib import pyplot as plt

variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

# plt.plotを複数回呼び出して、1つのグラフに複数の線を描画
# http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot
plt.plot(xs, variance, 'g-', label='variance') # 緑の実線
plt.plot(xs, bias_squared, 'r-.', label='bias^2') # 赤の点線
plt.plot(xs, total_error, 'b:', label='total error') # 青の点線

# labelを指定すると凡例が自動で描かれる
plt.legend(loc=9) # 凡例の位置の制御 http://matplotlib.org/api/legend_api.html
plt.xlabel("model complexity")
plt.title("The Bias-Variance Tradeoff") # 過学習の話 http://chezou.hatenablog.com/entry/2016/05/29/215739
plt.show()

# %%
# 散布図
# 2つのデータの関係を可視化するのに適している

from matplotlib import pyplot as plt

friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

# 各店のラベル
for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
        xy=(friend_count, minute_count),
        xytext=(5, -5),
        textcoords='offset points')

plt.xlabel("# of friends")
plt.ylabel("daily miniutes spant on the site")
plt.title("Daily Minutes vs. Number of Friends")

plt.show()

# %%
# matplotlibが自動で決めたスケールでは上手く比較できないケース

from matplotlib import pyplot as plt

test_1_grades = [99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
plt.title("Axes Aren't Comparable")
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")
plt.show()

# %%
# matplotlibが自動で決めたスケールでは上手く比較できないケース
# plt.axis("equal")の呼び出しを加えることで値の変化をより性正確に表現可能

from matplotlib import pyplot as plt

test_1_grades = [99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
plt.axis("equal")

plt.title("Axes Aren't Comparable")
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")
plt.show()
